# %%
from random import shuffle
import tensorflow as tf 
import tensorflow.keras as keras
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPool2D, Dropout, BatchNormalization, Dense
from keras.preprocessing.image import ImageDataGenerator
from sklearn import preprocessing
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import time
import sys
from tensorflow.python.keras.engine.data_adapter import train_validation_split

from tensorflow.python.keras.engine.sequential import relax_input_shape

# %%
train_image_path = './images/images/train/'
test_image_path = './images/images/test/'

train_csv = './assignment5_training_data_metadata.csv'
test_csv = './assignment5_test_data_metadata.csv'
df = pd.read_csv(train_csv)
df_test = pd.read_csv(test_csv)

df['type'].fillna('Normal', inplace=True)  # 1 - Normal, 2 - virus, 3 - bacteria, 4- stress smoking
df['type'].replace('Normal', 1, inplace=True)
df['type'].replace('Virus', 2, inplace=True)
df['type'].replace('bacteria', 3, inplace=True)
df['type'].replace('Stress-Smoking', 2, inplace=True) # I should just remove this from the dataset. 

unique, counts = np.unique(np.array(df['type']), return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {1: 1342, 2: 1409, 3: 2535}

# %%
img_height, img_width = 256, 256

training_data = []
testing_data = []

def create_data():
    for filename, filetype in zip(df['image_name'], df['type']): 
        img = cv2.imread((train_image_path + filename), cv2.IMREAD_GRAYSCALE)
        new = cv2.resize(img, (img_height, img_width))
        training_data.append([new, filetype])
        
    for filename, fileidx in zip(df_test['image_name'], df_test['id']): 
        img = cv2.imread((test_image_path + filename), cv2.IMREAD_GRAYSCALE)
        new = cv2.resize(img, (img_height, img_width))
        testing_data.append([new, fileidx])

# %%
# create_data()

# import random
# random.shuffle(training_data)
# # random.shuffle(testing_data)

# X = []
# y = []
# X_test = []
# id_test = []

# for features, label in training_data:
#     X.append(features)
#     y.append(label)
    
# for features, idx in testing_data:
#     X_test.append(features)
#     id_test.append(idx)

# X = np.array(X).reshape(-1, img_width, img_height, 1)
# X_test = np.array(X_test).reshape(-1, img_width, img_height, 1)
# y = np.array(y)
# id_test = np.array(id_test)

# with open('./pickles/X.pickle', 'wb') as handle:
#     pickle.dump(X, handle)
# with open('./pickles/y.pickle', 'wb') as handle:
#     pickle.dump(y, handle)
# with open('./pickles/X_test.pickle', 'wb') as handle:
#     pickle.dump(X_test, handle)
# with open('./pickles/id_test.pickle', 'wb') as handle:
#     pickle.dump(id_test, handle)

# %%
with open('./pickles/X.pickle', 'rb') as handle:
    X = pickle.load(handle)
with open('./pickles/y.pickle', 'rb') as handle:
    y = pickle.load(handle)
with open('./pickles/X_test.pickle', 'rb') as handle:
    X_test = pickle.load(handle)
with open('./pickles/id_test.pickle', 'rb') as handle:
    id_test = pickle.load(handle)

# %%
X = X/255.0
X_test = X_test/255.0

# %%
ohe = preprocessing.OneHotEncoder()
categories = np.array(y.reshape(-1,1))
y_ohe = ohe.fit_transform(categories).todense()
y_1 = np.array(y_ohe)

# %%
from sklearn.utils.class_weight import compute_class_weight
y_integers = np.argmax(y_1, axis=1)
class_weights = compute_class_weight('balanced', np.unique(y_integers), y_integers)
d_class_weights = dict(enumerate(class_weights))
# Out:
# /home/brendan/anaconda3/envs/a5/lib/python3.9/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass classes=[0 1 2], y=[2 1 1 ... 0 2 0] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
d_class_weights
# Out:
# {0: 1.3129657228017884, 1: 1.2505322924059616, 2: 0.695069033530572}

# %%
# NAME = 'testing_{}'.format(time.time())
# tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME))

# model = Sequential()

# model.add(Conv2D(32, (3,3), activation='relu', input_shape=X.shape[1:]))

# model.add(Conv2D(32, (3,3), activation='relu'))
# model.add(MaxPool2D(2))

# model.add(Conv2D(64, (3,3), activation='relu'))
# model.add(MaxPool2D(2))

# model.add(Conv2D(128, (3,3), activation='relu'))
# model.add(MaxPool2D(2))

# model.add(Conv2D(256, (3,3), activation='relu'))
# model.add(MaxPool2D(2))

# model.add(Conv2D(512, (3,3), activation='relu'))
# model.add(MaxPool2D(2))


# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dense(3, activation='softmax'))

# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# model.summary()

# early = EarlyStopping(monitor='val_loss', mode='min', patience=3)
# learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
# callbacks_list = [ early, learning_rate_reduction, tensorboard ]

# history = model.fit(X, y_ohe, epochs=25, validation_split=0.2, batch_size=32, class_weight=d_class_weights, callbacks=[callbacks_list])

# %%
dense_layers = [0, 1, 2, 3]
layer_sizes = [64, 128, 256, 512, 1024]
conv_layers = [4, 5, 6]

flag = True
idx = 0
for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            if flag:
                if  idx == 4:
                    flag = False
                idx = idx + 1
                continue
            try:
                NAME = '{}-conv-{}-nodes-{}-dense-{}'.format(conv_layer, layer_size, dense_layer, int(time.time()))
                tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME))

                model = keras.Sequential()

                model.add(Conv2D(layer_size, 3, activation='relu', input_shape=X.shape[1:]))

                for l in range(conv_layer - 1):
                    model.add(Conv2D(layer_size, 3, activation='relu'))
                    model.add(MaxPool2D(2))
#                     model.add(Dropout(0.25))


                model.add(Flatten())
                for l in range(dense_layer):
                    model.add(Dense(layer_size, activation='relu'))
                model.add(Dense(3, activation='softmax'))
                
                model.summary()
                
                model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
                
                early = EarlyStopping(monitor='val_loss', mode='min', patience=3)
                learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
                callbacks_list = [ early, learning_rate_reduction, tensorboard ]
                
                model.fit(X, y_ohe, epochs=25, validation_split=0.2, batch_size=32, class_weight=d_class_weights, callbacks=[callbacks_list])
                
                model.save('./models/{}'.format(NAME))
            except Exception as e: #trying to stop OOM if I get them and just continue on
                print(str(e))
                continue
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 64)      640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 252, 252, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 126, 126, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 124, 124, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 6915
# =================================================================
# Total params: 192,195
# Trainable params: 192,195
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 133/133 [==============================] - 62s 354ms/step - loss: 0.9672 - accuracy: 0.4434 - val_loss: 0.6977 - val_accuracy: 0.6465
# Epoch 2/25
# 133/133 [==============================] - 23s 176ms/step - loss: 0.5546 - accuracy: 0.7422 - val_loss: 0.5508 - val_accuracy: 0.7505
# Epoch 3/25
# 133/133 [==============================] - 23s 176ms/step - loss: 0.5138 - accuracy: 0.7574 - val_loss: 0.4960 - val_accuracy: 0.7807
# Epoch 4/25
# 133/133 [==============================] - 23s 175ms/step - loss: 0.4729 - accuracy: 0.7755 - val_loss: 0.5235 - val_accuracy: 0.7495
# Epoch 5/25
# 133/133 [==============================] - 23s 175ms/step - loss: 0.4295 - accuracy: 0.7908 - val_loss: 0.5011 - val_accuracy: 0.7854
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 6/25
# 133/133 [==============================] - 23s 170ms/step - loss: 0.3899 - accuracy: 0.8131 - val_loss: 0.4301 - val_accuracy: 0.8100
# Epoch 7/25
# 133/133 [==============================] - 24s 180ms/step - loss: 0.3771 - accuracy: 0.8200 - val_loss: 0.4751 - val_accuracy: 0.7864
# Epoch 8/25
# 133/133 [==============================] - 26s 195ms/step - loss: 0.3488 - accuracy: 0.8322 - val_loss: 0.4654 - val_accuracy: 0.7996
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 9/25
# 133/133 [==============================] - 24s 181ms/step - loss: 0.3100 - accuracy: 0.8490 - val_loss: 0.4562 - val_accuracy: 0.8043
# INFO:tensorflow:Assets written to: ./models/6-conv-64-nodes-0-dense-1618084394/assets
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 254, 254, 128)     1280
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8258048)           0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 24774147
# =================================================================
# Total params: 24,775,427
# Trainable params: 24,775,427
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 133/133 [==============================] - 27s 184ms/step - loss: 20.3366 - accuracy: 0.5219 - val_loss: 0.4981 - val_accuracy: 0.7873
# Epoch 2/25
# 133/133 [==============================] - 22s 168ms/step - loss: 0.3920 - accuracy: 0.8377 - val_loss: 0.4887 - val_accuracy: 0.7930
# Epoch 3/25
# 133/133 [==============================] - 21s 158ms/step - loss: 0.2857 - accuracy: 0.8784 - val_loss: 0.5057 - val_accuracy: 0.7873
# Epoch 4/25
# 133/133 [==============================] - 21s 161ms/step - loss: 0.1954 - accuracy: 0.9217 - val_loss: 0.5186 - val_accuracy: 0.8062
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 5/25
# 133/133 [==============================] - 22s 165ms/step - loss: 0.0977 - accuracy: 0.9670 - val_loss: 0.5439 - val_accuracy: 0.7996
# INFO:tensorflow:Assets written to: ./models/1-conv-128-nodes-0-dense-1618084648/assets
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 254, 254, 128)     1280
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 252, 252, 128)     147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 126, 126, 128)     0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2032128)           0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 6096387
# =================================================================
# Total params: 6,245,251
# Trainable params: 6,245,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 133/133 [==============================] - 64s 456ms/step - loss: 2.9993 - accuracy: 0.5452 - val_loss: 0.6579 - val_accuracy: 0.7278
# Epoch 2/25
# 133/133 [==============================] - 62s 469ms/step - loss: 0.5127 - accuracy: 0.7716 - val_loss: 0.5358 - val_accuracy: 0.7864
# Epoch 3/25
# 133/133 [==============================] - 61s 461ms/step - loss: 0.3647 - accuracy: 0.8411 - val_loss: 0.5666 - val_accuracy: 0.7675
# Epoch 4/25
# 133/133 [==============================] - 60s 449ms/step - loss: 0.2701 - accuracy: 0.8900 - val_loss: 0.6056 - val_accuracy: 0.7760
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 5/25
# 133/133 [==============================] - 57s 427ms/step - loss: 0.1244 - accuracy: 0.9490 - val_loss: 0.6351 - val_accuracy: 0.7807
# INFO:tensorflow:Assets written to: ./models/2-conv-128-nodes-0-dense-1618084763/assets
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 254, 254, 128)     1280
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 252, 252, 128)     147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 126, 126, 128)     0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 124, 124, 128)     147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 62, 62, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 492032)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 1476099
# =================================================================
# Total params: 1,772,547
# Trainable params: 1,772,547
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 133/133 [==============================] - 71s 501ms/step - loss: 1.1434 - accuracy: 0.5525 - val_loss: 0.5927 - val_accuracy: 0.7439
# Epoch 2/25
# 133/133 [==============================] - 61s 456ms/step - loss: 0.4926 - accuracy: 0.7837 - val_loss: 0.5465 - val_accuracy: 0.7807
# Epoch 3/25
# 133/133 [==============================] - 60s 452ms/step - loss: 0.4028 - accuracy: 0.8042 - val_loss: 0.4930 - val_accuracy: 0.7958
# Epoch 4/25
# 133/133 [==============================] - 58s 434ms/step - loss: 0.3228 - accuracy: 0.8516 - val_loss: 0.5388 - val_accuracy: 0.7760
# Epoch 5/25
# 133/133 [==============================] - 64s 480ms/step - loss: 0.2524 - accuracy: 0.8778 - val_loss: 0.5920 - val_accuracy: 0.7779
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 6/25
# 133/133 [==============================] - 63s 477ms/step - loss: 0.1900 - accuracy: 0.9178 - val_loss: 0.6765 - val_accuracy: 0.7665
# INFO:tensorflow:Assets written to: ./models/3-conv-128-nodes-0-dense-1618085068/assets
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 254, 254, 128)     1280
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 252, 252, 128)     147584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 126, 126, 128)     0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 124, 124, 128)     147584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 62, 62, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 60, 60, 128)       147584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 30, 30, 128)       0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 115200)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 345603
# =================================================================
# Total params: 789,635
# Trainable params: 789,635
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 133/133 [==============================] - 70s 500ms/step - loss: 0.9734 - accuracy: 0.5063 - val_loss: 0.5664 - val_accuracy: 0.7495
# Epoch 2/25
# 133/133 [==============================] - 60s 452ms/step - loss: 0.5018 - accuracy: 0.7664 - val_loss: 0.4643 - val_accuracy: 0.7968
# Epoch 3/25
# 133/133 [==============================] - 62s 464ms/step - loss: 0.4379 - accuracy: 0.7910 - val_loss: 0.5586 - val_accuracy: 0.7287
# Epoch 4/25
# 133/133 [==============================] - 62s 464ms/step - loss: 0.4035 - accuracy: 0.8036 - val_loss: 0.4638 - val_accuracy: 0.8062
# Epoch 5/25
# 133/133 [==============================] - 60s 455ms/step - loss: 0.3504 - accuracy: 0.8257 - val_loss: 0.5199 - val_accuracy: 0.7968
# Epoch 6/25
# 133/133 [==============================] - 61s 460ms/step - loss: 0.2872 - accuracy: 0.8673 - val_loss: 0.5756 - val_accuracy: 0.7911
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 7/25
# 133/133 [==============================] - 60s 452ms/step - loss: 0.2546 - accuracy: 0.8852 - val_loss: 0.5905 - val_accuracy: 0.8015
# INFO:tensorflow:Assets written to: ./models/4-conv-128-nodes-0-dense-1618085446/assets
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 254, 254, 128)     1280
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 252, 252, 128)     147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 126, 126, 128)     0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 124, 124, 128)     147584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 62, 62, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 60, 60, 128)       147584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 75267
# =================================================================
# Total params: 666,883
# Trainable params: 666,883
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 133/133 [==============================] - 70s 494ms/step - loss: 0.8931 - accuracy: 0.5320 - val_loss: 0.6735 - val_accuracy: 0.6966
# Epoch 2/25
# 133/133 [==============================] - 60s 453ms/step - loss: 0.5239 - accuracy: 0.7516 - val_loss: 0.5408 - val_accuracy: 0.7533
# Epoch 3/25
# 133/133 [==============================] - 66s 500ms/step - loss: 0.4761 - accuracy: 0.7840 - val_loss: 0.4942 - val_accuracy: 0.7911
# Epoch 4/25
# 133/133 [==============================] - 65s 491ms/step - loss: 0.3946 - accuracy: 0.8210 - val_loss: 0.5536 - val_accuracy: 0.7684
# Epoch 5/25
# 133/133 [==============================] - 63s 473ms/step - loss: 0.3835 - accuracy: 0.8166 - val_loss: 0.5547 - val_accuracy: 0.7722
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 6/25
# 133/133 [==============================] - 63s 472ms/step - loss: 0.3255 - accuracy: 0.8475 - val_loss: 0.5434 - val_accuracy: 0.7817
# INFO:tensorflow:Assets written to: ./models/5-conv-128-nodes-0-dense-1618085882/assets
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 254, 254, 128)     1280
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 252, 252, 128)     147584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 126, 126, 128)     0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 124, 124, 128)     147584
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 62, 62, 128)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 60, 60, 128)       147584
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 12, 12, 128)       147584
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 13827
# =================================================================
# Total params: 753,027
# Trainable params: 753,027
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
#   1/133 [..............................] - ETA: 11:41 - loss: 1.0341 - accuracy: 0.5000

# %%
model.save('./models/softamx_{:.4}'.format(history.history['val_accuracy'][-1]))

# %%
# model = keras.models.load_model('./models/sigmoid_testing_1618075828.1710396')

# %%
pred = model.predict_classes(X_test)
# pred_ = np.argmax(model.predict(X_test), axis=-1) # this is the non-deprecated version

# %%
pred = pred+1

# %%
output = pd.DataFrame({'id': id_test, 'type': pred})
output.to_csv('prediction.csv', index=False)
